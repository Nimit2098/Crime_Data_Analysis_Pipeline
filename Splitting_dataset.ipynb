# %%
#importing necessary libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#reading the dataset
df = pd.read_csv("Dataset\Police_Department_Incident_Reports__2018_to_Present (2).csv")

# %%
df.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023  \
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID
# 0               Monday  2023/03/13 11:41:00 PM  125373607041      1253736  \
# 1            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2               Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
#
#    Incident Number  CAD Number Report Type Code Report Type Description
# ...

# %%
#Splitting the dataframe into 3 chuncks for better handling
[df_1,df_2,df_3] = np.array_split(df, 3)

# %%
df_2
# Out:
#              Incident Datetime Incident Date Incident Time  Incident Year
# 257533  2022/10/08 11:14:00 PM    2022/10/08         23:14           2022  \
# 257534  2022/12/31 07:25:00 PM    2022/12/31         19:25           2022
# 257535  2023/01/01 11:00:00 AM    2023/01/01         11:00           2023
# 257536  2022/09/18 12:20:00 PM    2022/09/18         12:20           2022
# 257537  2022/12/29 10:00:00 AM    2022/12/29         10:00           2022
# ...                        ...           ...           ...            ...
# 515061  2018/08/30 05:30:00 PM    2018/08/30         17:30           2018
# 515062  2018/12/05 09:00:00 PM    2018/12/05         21:00           2018
# 515063  2018/11/24 08:00:00 PM    2018/11/24         20:00           2018
# 515064  2018/11/17 12:05:00 AM    2018/11/17         00:05           2018
# 515065  2018/11/18 08:20:00 PM    2018/11/18         20:20           2018
#
#        Incident Day of Week         Report Datetime        Row ID
# ...

# %% [markdown]
# ### To join all the parts of the csv files into one dataset, use the below code.

# %%
#joining all the parts of the original dataframe
df_check = pd.concat([df_1,df_2,df_3])

# %%
df_check.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023  \
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID
# 0               Monday  2023/03/13 11:41:00 PM  125373607041      1253736  \
# 1            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2               Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
#
#    Incident Number  CAD Number Report Type Code Report Type Description
# ...

# %%
#Saving the split dataframe into csv files.
df_1.to_csv(r'Dataset/Part_1_Police_Department_Incident_Reports__2018_to_Present.csv')
df_2.to_csv(r'Dataset/Part_2_Police_Department_Incident_Reports__2018_to_Present.csv')
df_3.to_csv(r'Dataset/Part_3Police_Department_Incident_Reports__2018_to_Present.csv')
